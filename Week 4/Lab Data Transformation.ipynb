# %%
# Exercise 1.

#Import File
import pandas as pd
file_path = r'C:\Users\flori\Downloads\marketing_customer_analysis_clean.csv'

df_marketing = pd.read_csv(file_path)

# %%
# Load DF
df_marketing
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
# Create Categprical and Numbercial DF

categorical_df = df_marketing.select_dtypes(include='object')
numericals_df = df_marketing.select_dtypes(include ='number')

# %%
#Load categorical df
categorical_df
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College        2011-02-18
# 1      KX64629  California       No     Basic   College        2011-01-18
# 2      LZ68649  Washington       No     Basic  Bachelor        2011-02-10
# 3      XL78013      Oregon      Yes  Extended   College        2011-01-11
# 4      QA50777      Oregon       No   Premium  Bachelor        2011-01-17
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor        2011-01-19
# 10906  KX53892      Oregon       No     Basic   College        2011-01-06
# 10907  TL39050     Arizona       No  Extended  Bachelor        2011-02-06
# 10908  WA60547  California       No   Premium   College        2011-02-13
# 10909  IV32877  California       No     Basic  Bachelor        2011-01-08
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
categorical_df.customer.unique()
# Out:
# array(['DK49336', 'KX64629', 'LZ68649', ..., 'KX53892', 'TL39050',
#        'WA60547'], dtype=object)

# %%
#Create nominal df
nominals_df = pd.get_dummies(categorical_df[['state', 'response', 'employmentstatus', 'gender', 'location_code','marital_status', 'policy_type','policy', 'renew_offer_type','sales_channel','vehicle_class', 'vehicle_type']], dtype=int)

# %%
# Check nominal df
nominals_df
# Out:
#        state_Arizona  state_California  state_Nevada  state_Oregon  \
# 0                  1                 0             0             0
# 1                  0                 1             0             0
# 2                  0                 0             0             0
# 3                  0                 0             0             1
# 4                  0                 0             0             1
# ...              ...               ...           ...           ...
# 10905              0                 0             1             0
# 10906              0                 0             0             1
# 10907              1                 0             0             0
# 10908              0                 1             0             0
# 10909              0                 1             0             0
#
#        state_Washington  response_No  response_Yes  employmentstatus_Disabled  \
# 0                     0            1             0                          0
# ...

# %%
# Ordinal columns
# create a new DF
# Out:
#   Cell In[47], line 2
#     create a new DF
#            ^
# SyntaxError: invalid syntax

# %%
# Coverage
categorical_df.coverage.unique()
# Out:
# array(['Basic', 'Extended', 'Premium'], dtype=object)

# %%
new_categorical_df=categorical_df["coverage"].map({'Basic':0, 'Extended':1, 'Premium':2})

# %%
# Education

# %%
categorical_df.education.unique()
# Out:
# array(['College', 'Bachelor', 'High School or Below', 'Doctor', 'Master'],
#       dtype=object)

# %%
new_categorical_df= categorical_df["education"].map({'High School or Below':0, 'College': 1, 'Bachelor':2, 'Master':3, 'Doctor':4})

# %%
#Vehicle Size
categorical_df.vehicle_size.unique()
# Out:
# array(['Medsize', 'Small', 'Large'], dtype=object)

# %%
new_categorical_df=categorical_df['vehicle_size'].map({'Small': 0, 'Medsize': 1, 'Large' :2})

# %%
concatenated_df = pd.concat([new_categorical_df, nominals_df], axis=1)

# %%
concatenated_df
# Out:
#        vehicle_size  state_Arizona  state_California  state_Nevada  \
# 0                 1              1                 0             0
# 1                 1              0                 1             0
# 2                 1              0                 0             0
# 3                 1              0                 0             0
# 4                 1              0                 0             0
# ...             ...            ...               ...           ...
# 10905             1              0                 0             1
# 10906             1              0                 0             0
# 10907             1              1                 0             0
# 10908             1              0                 1             0
# 10909             1              0                 1             0
#
#        state_Oregon  state_Washington  response_No  response_Yes  \
# 0                 0                 0            1             0
# ...

# %%
#Ordinal Encoder -> not used

from sklearn.preprocessing import OrdinalEncoder

ordinal_columns = ['coverage', 'education', 'vehicle_size']

# %%
ordinal_encoder = OrdinalEncoder()

# %%
ordinal_df[ordinal_columns] = ordinal_encoder.fit_transform(ordinal_df[ordinal_columns])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 ordinal_df[ordinal_columns] = ordinal_encoder.fit_transform(ordinal_df[ordinal_columns])
#
# NameError: name 'ordinal_df' is not defined

# %%
#load numericals_df
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %%
print(df_marketing.dtypes)
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
# Exercise 2
numericals_df
# Out:
# <Axes: >

# %%
numericals_df["customer_lifetime_value"].hist()
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %%
import matplotlib.pyplot as plt

selected_columns = ["customer_lifetime_value", "income", "monthly_premium_auto",
                    "months_since_last_claim", "months_since_policy_inception",
                    "number_of_open_complaints", "number_of_policies",
                    "total_claim_amount", "month"]

numericals_df[selected_columns].hist(bins=10, figsize=(12, 10), layout=(3, 3), sharex=False)
plt.suptitle('Histograms of Selected Numerical Features', y=1.02, fontsize=16)
plt.show()

# %%
# Define variables

# varA = 'month_since_last_claim' wide range
# varB = customer_lifetime_value wide skew

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer
scaler = MinMaxScaler()

# %%
numericals_df["last_claim_minmax"] = scaler.fit_transform(numericals_df[["months_since_last_claim"]])

# %%
# Display the DataFrame with the new column
print(numericals_df)
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %%
numericals_df["last_claim_minmax"].hist()
# Out:
# <Axes: >

# %%
# varB 
#Use StandardScaler to standardize the variable or PowerTransform to reduce its skew.
#Check that the result has zero mean, unit variance, and reduced skew using mean(), std(), and a plot of the PDF.

scaler = StandardScaler()
scaler.fit_transform(numericals_df[["customer_lifetime_value"]])
# Out:
# array([[-0.46610505],
#        [-0.84094593],
#        [ 1.00652314],
#        ...,
#        [ 2.30582467],
#        [ 0.5742732 ],
#        [-0.16859268]])

# %%
pt = PowerTransformer()

# %%
numericals_df.customer_lifetime_value.hist()
# Out:
# <Axes: >

# %%
numericals_df["customer_lifetime_value_pt"] = pt.fit_transform(numericals_df[["customer_lifetime_value"]])

# %%
numericals_df["customer_lifetime_value_pt"].hist()
# Out:
# <Axes: >

# %%
numericals_df.describe()
# Out:
#          unnamed:_0  customer_lifetime_value        income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        monthly_premium_auto  months_since_last_claim  \
# count          10910.000000             10910.000000
# mean              93.196059                15.149071
# std               34.442532                 9.783520
# min               61.000000                 0.000000
# 25%               68.000000                 7.000000
# 50%               83.000000                15.000000
# 75%              109.000000                23.000000
# ...
